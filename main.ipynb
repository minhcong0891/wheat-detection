# %% [markdown]
# #Import suitable packages
# Reference:
#
# https://medium.com/ai-world/how-to-train-yolov4-for-custom-objects-detection-in-google-colab-1e934b8ef685
#
# https://github.com/rafiuddinkhan/Yolo-Training-GoogleColab
#
# Fixing reference:
#
# https://github.com/NVIDIA/flownet2-pytorch/issues/86
#
# https://arnon.dk/matching-sm-architectures-arch-and-gencode-for-various-nvidia-cards/

# %%
import numpy as np
import pandas as pd
import cv2
import random
from google.colab import drive
import torch
import tensorflow as tf

# %% [markdown]
# # Mount the google drive data file

# %%
drive.mount('/content/gdrive', force_remount=True)
# Not Necessary cell
# List the content of your local computer folder 
# !ls -la "/content/gdrive/My\ Drive"
# !sudo apt-get install tree
# !tree /content/gdrive/My\ Drive
#!ln -s "/content/gdrive/My\ Drive/darknet-master/" /mydrive
# Out:
# Streaming output truncated to the last 5000 lines.
# │   │   │   ├── 4f14fa438.txt
# │   │   │   ├── 4f4b7779a.jpg
# │   │   │   ├── 4f4b7779a.txt
# │   │   │   ├── 4f4c6ee91.jpg
# │   │   │   ├── 4f4c6ee91.txt
# │   │   │   ├── 4f5331b7b.jpg
# │   │   │   ├── 4f5331b7b.txt
# │   │   │   ├── 4f75a8d52.jpg
# │   │   │   ├── 4f75a8d52.txt
# │   │   │   ├── 4f9b8d33e.jpg
# │   │   │   ├── 4f9b8d33e.txt
# │   │   │   ├── 4f9eceb2b.jpg
# │   │   │   ├── 4f9eceb2b.txt
# │   │   │   ├── 4fb0ce1e5.jpg
# │   │   │   ├── 4fb0ce1e5.txt
# │   │   │   ├── 4fb926950.jpg
# │   │   │   ├── 4fb926950.txt
# │   │   │   ├── 4fbf0c8b7.jpg
# │   │   │   ├── 4fbf0c8b7.txt
# │   │   │   ├── 4fc5adf2d.jpg
# │   │   │   ├── 4fc5adf2d.txt
# │   │   │   ├── 4ff1646a8.jpg
# │   │   │   ├── 4ff1646a8.txt
# │   │   │   ├── 4ffeedce2.jpg
# │   │   │   ├── 4ffeedce2.txt
# │   │   │   ├── 5016adc4b.jpg
# │   │   │   ├── 5016adc4b.txt
# │   │   │   ├── 5018112f2.jpg
# │   │   │   ├── 5018112f2.txt
# ...

# %% [markdown]
# # Check version of opencv and CUDA (GPU)

# %%
# This cell can be commented once you checked the current CUDA version
# CUDA: Let's check that Nvidia CUDA is already pre-installed and which version is it. In some time from now maybe you 
# !nvidia-smi
#!/usr/local/cuda/bin/nvcc --version
# !/usr/local/cuda/bin/nvcc --version
!--generate-code arch=sm_75,code=compute_75
#!nvcc --gpu-architecture=sm_75
#!nvcc --help
#!-O2 -o mykernel.o -c mykernel.cu
#Check PyTorch is capable of using GPU
torch.cuda.is_available()
tf.test.gpu_device_name()
# Out:
# Mon Sep 28 01:11:41 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# #Build make file to training

# %%
# %cd "/content/gdrive/My Drive/darknet-master/"
# !make
# !chmod +x ./darknet
# Out:
# /content/gdrive/My Drive/darknet-master
# chmod +x *.sh

# %% [markdown]
# #Train darknet model

# %%
! ./darknet detector train data/wheat.data cfg/yolov4-wheat.cfg yolov4-wheat_last.weights
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# yolov4-wheat
#  compute_capability = 600, cudnn_half = 0
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
# ...

# %% [markdown]
# # Test with sample

# %%
# !./darknet detector test data/wheat.data cfg/yolov4-wheat.cfg backup/yolov4-wheat_final.weights -dont_show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  compute_capability = 600, cudnn_half = 0
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    8 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
# ...

# %% [markdown]
# # Show prediction image

# %%
# !cv2.imshow('darknet-master/predictions.png')
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `'darknet-master/predictions.png''
# /bin/bash: -c: line 0: `cv2.imshow('darknet-master/predictions.png')'
